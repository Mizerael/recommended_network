# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/SpotifyFeatures.csv')
data
# Out:
#         genre               artist_name                        track_name
# 0       Movie            Henri Salvador       C'est beau de faire un Show  \
# 1       Movie         Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2       Movie           Joseph Williams    Don't Let Me Be Lonely Tonight
# 3       Movie            Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4       Movie              Fabien Nataf                         Ouverture
# ...       ...                       ...                               ...
# 232720   Soul                     Slave                      Son Of Slide
# 232721   Soul  Jr Thomas & The Volcanos                      Burning Fire
# 232722   Soul              Muddy Waters    (I'm Your) Hoochie Coochie Man
# 232723   Soul                   R.LUM.R                     With My Words
# 232724   Soul            Mint Condition    You Don't Have To Hurt No More
#
#                       track_id  popularity  acousticness  danceability
# ...

# %%
data[data.genre == "Anime"][data.popularity < 10]
# Out:
# /tmp/ipykernel_348/1553514584.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data.genre == "Anime"][data.popularity < 10]
#        genre      artist_name                             track_name
# 27854  Anime  Hiroyuki Sawano         Uncontrollable (N.Z.K.) - Live  \
# 28176  Anime     Joe Hisaishi  The Name of Life - Piano Solo Version
# 28836  Anime            Rozen                 Mataram - Original Mix
# 31351  Anime    Mashiro Ayano                             Confession
# 31431  Anime    Mashiro Ayano              Confession - Instrumental
# ...      ...              ...                                    ...
# 45618  Anime  Bruce Faulconer                         Android Battle
# 45622  Anime  Masaru Yokoyama                      All Day,All Night
# 45624  Anime     Naoyuki Onda                             Winterfall
# 45626  Anime     Naoyuki Onda                              Night Sky
# ...

# %%
from sklearn.cluster import KMeans
